# %% [markdown]
# <a href="https://colab.research.google.com/github/freddyambia/Data-Science-I/blob/master/Examen2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
##Pregunta 1
df_datos01=pd.read_csv("TB_FALLECIDO_HOSP_VAC.csv",sep=",")
print("Se importó data y se asignó a df_datos01")
# Out:
# Se importó data y se asignó a df_datos01

# %%
##Conociendo la Data
df_datos01.head()
# Out:
#    id_persona fecha_fallecimiento  edad sexo    criterio_fallecido  \
# 0    33779814           6/05/2021    48    F      Criterio SINADEF
# 1     5611276          30/12/2021    43    M  Criterio virolÃ³gico
# 2     3797139          13/05/2021    61    M      Criterio SINADEF
# 3    15290577          30/04/2021    74    M  Criterio serolÃ³gico
# 4     4385089          17/04/2021    54    F  Criterio virolÃ³gico
#
#    ubigeo_cdc      dpt_cdc  prov_cdc           dist_cdc  cdc_positividad  ...  \
# 0      150117         LIMA      LIMA         LOS OLIVOS                0  ...
# 1      150117         LIMA      LIMA         LOS OLIVOS                1  ...
# 2      140120   LAMBAYEQUE  CHICLAYO              TUMAN                0  ...
# 3      150120         LIMA      LIMA  MAGDALENA DEL MAR                0  ...
# 4      130105  LA LIBERTAD  TRUJILLO       LA ESPERANZA                0  ...
#
#    fecha_ingreso_uci fecha_ingreso_ucin con_oxigeno con_ventilacion  \
# ...

# %%
df_datos01.head()
# Out:
#    id_persona fecha_fallecimiento  edad sexo    criterio_fallecido  \
# 0    33779814           6/05/2021    48    F      Criterio SINADEF
# 1     5611276          30/12/2021    43    M  Criterio virolÃ³gico
# 2     3797139          13/05/2021    61    M      Criterio SINADEF
# 3    15290577          30/04/2021    74    M  Criterio serolÃ³gico
# 4     4385089          17/04/2021    54    F  Criterio virolÃ³gico
#
#    ubigeo_cdc      dpt_cdc  prov_cdc           dist_cdc  cdc_positividad  ...  \
# 0      150117         LIMA      LIMA         LOS OLIVOS                0  ...
# 1      150117         LIMA      LIMA         LOS OLIVOS                1  ...
# 2      140120   LAMBAYEQUE  CHICLAYO              TUMAN                0  ...
# 3      150120         LIMA      LIMA  MAGDALENA DEL MAR                0  ...
# 4      130105  LA LIBERTAD  TRUJILLO       LA ESPERANZA                0  ...
#
#    fecha_ingreso_uci fecha_ingreso_ucin con_oxigeno con_ventilacion  \
# ...

# %%
##Tamaño total de datos
df_datos01.shape
# Out:
# (107768, 34)

# %%
##Tamaño total de datos
df_datos01.size
# Out:
# 3664112

# %%
##Columnas con datos nulos:
df_datos01.info()
print("")
print("El número de datos es de 107768 como se indica en el reporte")
print("Las columnas con datos nulos son las que cuentan con ")
print("menos valores 'No nulos' en la tabla anterior")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107768 entries, 0 to 107767
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   id_persona                    107768 non-null  int64
#  1   fecha_fallecimiento           107768 non-null  object
#  2   edad                          107768 non-null  int64
#  3   sexo                          107767 non-null  object
#  4   criterio_fallecido            107768 non-null  object
#  5   ubigeo_cdc                    107768 non-null  int64
#  6   dpt_cdc                       107768 non-null  object
#  7   prov_cdc                      107768 non-null  object
#  8   dist_cdc                      107768 non-null  object
#  9   cdc_positividad               107768 non-null  int64
#  10  flag_vacuna                   107768 non-null  int64
#  11  fecha_dosis1                  9462 non-null    object
# ...

# %%
df_datos01.isnull()
# Out:
#         id_persona  fecha_fallecimiento   edad   sexo  criterio_fallecido  \
# 0            False                False  False  False               False
# 1            False                False  False  False               False
# 2            False                False  False  False               False
# 3            False                False  False  False               False
# 4            False                False  False  False               False
# ...            ...                  ...    ...    ...                 ...
# 107763       False                False  False  False               False
# 107764       False                False  False  False               False
# 107765       False                False  False  False               False
# 107766       False                False  False  False               False
# 107767       False                False  False  False               False
#
#         ubigeo_cdc  dpt_cdc  prov_cdc  dist_cdc  cdc_positividad  ...  \
# ...

# %%
print(df_datos01.describe)
# Out:
# <bound method NDFrame.describe of         id_persona fecha_fallecimiento  edad sexo    criterio_fallecido  \
# 0         33779814           6/05/2021    48    F      Criterio SINADEF
# 1          5611276          30/12/2021    43    M  Criterio virolÃ³gico
# 2          3797139          13/05/2021    61    M      Criterio SINADEF
# 3         15290577          30/04/2021    74    M  Criterio serolÃ³gico
# 4          4385089          17/04/2021    54    F  Criterio virolÃ³gico
# ...            ...                 ...   ...  ...                   ...
# 107763     1591927          12/03/2021    55    F      Criterio SINADEF
# 107764     2537936           8/05/2021    89    F  Criterio virolÃ³gico
# 107765    13573531          24/04/2021    85    M      Criterio SINADEF
# 107766     3014961          13/03/2021    68    M  Criterio virolÃ³gico
# 107767    17007990          25/05/2021    30    F     Criterio clÃ­nico
#
# ...

# %%
Edad=df_datos01['edad']
Edad
# Out:
# 0         48
# 1         43
# 2         61
# 3         74
# 4         54
#           ..
# 107763    55
# 107764    89
# 107765    85
# 107766    68
# 107767    30
# Name: edad, Length: 107768, dtype: int64

# %%
Edad.max()
# Out:
# 117

# %%
Edad.min()
# Out:
# 0

# %%
df_limpi01=df_datos01[df_datos01['edad'] >15]

# %%
df_limpio01= df_limpi01[df_limpi01['edad'] <60]

# %%
df_limpio01.head()
# Out:
#    id_persona fecha_fallecimiento  edad sexo    criterio_fallecido  \
# 0    33779814           6/05/2021    48    F      Criterio SINADEF
# 1     5611276          30/12/2021    43    M  Criterio virolÃ³gico
# 4     4385089          17/04/2021    54    F  Criterio virolÃ³gico
# 5    22424254          12/05/2021    40    M  Criterio virolÃ³gico
# 7     1718681           1/05/2021    52    M  Criterio virolÃ³gico
#
#    ubigeo_cdc      dpt_cdc    prov_cdc      dist_cdc  cdc_positividad  ...  \
# 0      150117         LIMA        LIMA    LOS OLIVOS                0  ...
# 1      150117         LIMA        LIMA    LOS OLIVOS                1  ...
# 4      130105  LA LIBERTAD    TRUJILLO  LA ESPERANZA                0  ...
# 5      140201   LAMBAYEQUE  FERREÃAFE    FERREÃAFE                1  ...
# 7       70101       CALLAO      CALLAO        CALLAO                1  ...
#
#    fecha_ingreso_uci fecha_ingreso_ucin con_oxigeno con_ventilacion  \
# ...

# %%
df_limpio01.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-b8de47a4189d> in <module>()
# ----> 1 df_limpio01.shape()
#
# TypeError: 'tuple' object is not callable
