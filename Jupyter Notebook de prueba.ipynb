# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# #### Freddy Ambía Ramos#
# Estudiante de Administración y Recursos Humanos

# %% [markdown]
# ##### Estoy interesado en Data Science debido a que poseo cualidades que se adaptan al análisis de datos y a su aplicación en entornos laborales.

# %% [markdown]
# ### Se solicitará un input y se mostrará el mismo input

# %%
input( "La palabra que escribió es ")
# Out:
# La palabra que escribió es Avión
# 'Avión'

# %% [markdown]
# ## - Lista de viñetas
#  - Se inserta imagen
#  - ![mclovin.jpg](attachment:mclovin.jpg)
#  - Texto tachado <br>
#  - ~~Este texto ha sido tachado~~
#  - Hipervínculo
#  - [Página de UPC](http://www.upc.edu.pe)
